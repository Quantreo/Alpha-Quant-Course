# %%
import pandas as pd
import numpy as np
from itertools import combinations

import matplotlib.pyplot as plt
import os
import sys
import seaborn as sns
import itertools
import warnings
warnings.filterwarnings("ignore")
# Ajoutez le chemin du dossier parent à la variable d'environnement PYTHONPATH
parent_path = os.path.abspath("/Users/lucasinglese/Desktop/Alpha-Quant-Course-main")
sys.path.append(parent_path)

from Strategies.LI_2023_02_Ichimoku_1 import *
from Quantreo.Backtest import *

# %%
df = pd.read_csv("../Data/FixTimeBars/AUDUSD_4H_Admiral_READY.csv", index_col="time", parse_dates=True)

# %%
params = {
    "ichi_window_1": 7,
    "ichi_window_2": 26,
    "tp": 0.005,
    "sl": -0.005,
    "cost": 0.0001,
    "leverage": 5
}

BT = Backtest(df.loc["2019":], Ichimoku_1, params, run_directly=True)
# Out:
# ------------------------------------------------------------------------------------------------------------------
#  AVERAGE TRADE LIFETIME: 1D  31H  30M 	 Nb BUY: 53 	 Nb SELL: 196
#
#  Return (period): -10.20% 				 Maximum drawdown: 36.19%
#  HIT ratio: 50.00% 						 R ratio: 0.96
#  Best month return: 12.15% 				 Worse month return: -16.10%
#  Average ret/month: -0.20% 				 Profitable months: 44.00%
# ------------------------------------------------------------------------------------------------------------------
